# %% [markdown]
# # Semantic Decision Lab — Laya multilingual v0.1
#
# Run on a Colab **T4 GPU**. The provider/model revisions, 4096-token packing, frozen PDDR dataset, and shared Top-2 policy are fixed in the repository before provider output is observed.

# %%
# !nvidia-smi
# !rm -rf /content/semantic-decision-lab-laya
# !git clone https://github.com/serevy/semantic-decision-lab.git /content/semantic-decision-lab-laya
# %cd /content/semantic-decision-lab-laya
# !python experiments/context_selection/run_laya_multilingual_colab.py

# %% [markdown]
# After completion, preserve `/content/laya-multilingual-v0.1-results.zip` before changing any experiment condition.
