# %% [markdown]
# # Semantic Decision Lab — Open Jev v0.2 rematch
#
# Use a **Colab T4 GPU runtime**. The runner uses independent one-record packing and a **4096-token inference context**, and aborts unless all 21 frozen inputs preserve both the task and the complete PDDR record. If the exact v0.1 checkpoint is still present it is reused; otherwise the frozen v0.1 training configuration is rerun.

# %%
# !nvidia-smi
# !rm -rf /content/semantic-decision-lab-v02
# !git clone https://github.com/serevy/semantic-decision-lab.git /content/semantic-decision-lab-v02
# %cd /content/semantic-decision-lab-v02
# !python experiments/context_selection/run_open_jev_v02_colab.py

# %% [markdown]
# After the run finishes, preserve `experiments/context_selection/results/open-jev-v0.2/` and the generated ZIP before changing any experiment condition.
