# %% [markdown]
# # Semantic Decision Lab — Open Jev v0.2\n\nUse a **Colab T4 GPU runtime**. If the original v0.1 runtime is still alive, this notebook reuses its exact `jevlite.pt` checkpoint after verifying the SHA-256. Otherwise it retrains with the frozen configuration and records the new checkpoint hash.

# %%
# !nvidia-smi\n!rm -rf /content/semantic-decision-lab-v02\n!git clone https://github.com/serevy/semantic-decision-lab.git /content/semantic-decision-lab-v02\n%cd /content/semantic-decision-lab-v02\n!python experiments/context_selection/run_open_jev_v02_colab.py\n

# %% [markdown]
# When complete, preserve `/content/open-jev-v0.2-results.zip`. The runner also writes `input-preflight.json` beside the four provider result files.
