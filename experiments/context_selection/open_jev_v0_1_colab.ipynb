# %% [markdown]
# # Semantic Decision Lab — Open Jev v0.1\n\nRun this notebook in a **fresh Colab T4 GPU runtime**. The experiment conditions are already frozen in the repository. This notebook intentionally does not expose tuning controls.

# %%
# !nvidia-smi\n!git clone https://github.com/serevy/semantic-decision-lab.git\n%cd semantic-decision-lab\n!python experiments/context_selection/run_open_jev_colab.py\n

# %% [markdown]
# After the run finishes, inspect `experiments/context_selection/results/open-jev-v0.1/`. Preserve the four JSON files as first-run evidence before changing any experiment condition.
